# %%
"""
remove all whitespace(including \n and \t) of string,
just keep one space between the parts originally seperated by space
"""
def removeSpace(input_str):
    input_str = str(input_str)
    input_str.split()
    return ' '.join(input_str.split())

# %%
from pprint import pprint

import pickle
import json

import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
base_url = "http://www.edmunds.com"
year = "2015"

new_cars = base_url + "/new-cars/"
response = requests.get(new_cars)
html = response.content
car_make_soup = BeautifulSoup(html, 'lxml')

# %%
ss = car_make_soup.findAll('div', attrs = {'class': 'content grid-138'})[1]
s = ss.findAll('a')

makes = []
for item in s:
    m = str(item['href'].split('/')[1])
    makes.append(m)
    
urls = []
for m in makes:
    s = base_url + "/" + m
    urls.append(s)


crawl_list = []
car_list = []
for test in urls:
    model_response = requests.get(test)
    model_html = model_response.content
    model_soup = BeautifulSoup(model_html, 'lxml')

    s = model_soup.findAll('a', attrs = {'class': 'canonicalLink'})

    for item in s:
        temp = item['href']
        
        year_response = requests.get(base_url + temp)
        year_html = year_response.content
        year_soup = BeautifulSoup(year_html, 'lxml')
        
        for div in year_soup.findAll('div', class_='vehicle-card new-vm sh-none'):
            car_list.append(div.find('div', class_='info1').find('a')['href'])
            
with open('saved-data/car_list_url.pickle', 'w') as f:
    pickle.dump(car_list, f)

# %%
car_list = []
with open('saved-data/car_list_url.pickle', 'r') as f:
    car_url = pickle.load(f)
    
for car in car_url:
    temp = filter(None, car.split('/'))
    info = {}
    try:
        info['make'] = temp[0]
        info['model'] = temp[1]
        info['year'] = temp[2]
        info['type'] = temp[3]
        car_list.append(info)
    except:
        print temp
# Out:
# ['cadillac', 'ats-coupe', '2015']
# ['cadillac', 'ats-coupe', '2016']
# ['cadillac', 'cts-coupe', '2014']
# ['cadillac', 'cts-v-coupe', '2015']
# ['ford', 'transit-van', '2015']
# ['ford', 'transit-van', '2016']
# ['hyundai', 'genesis-coupe', '2015']
# ['hyundai', 'genesis-coupe', '2016']
# ['infiniti', 'q60-convertible', '2015']
# ['infiniti', 'q60-coupe', '2015']
# ['maserati', 'granturismo-convertible', '2015']
# ['maserati', 'granturismo-convertible', '2016']
# ['mclaren', '650s-coupe', '2015']
# ['ram', 'promaster-cargo-van', '2015']
# ['ram', 'promaster-cargo-van', '2016']
# ['ram', 'promaster-window-van', '2015']
# ['ram', 'promaster-window-van', '2016']
# ['rolls-royce', 'phantom-coupe', '2015']
# ['rolls-royce', 'phantom-coupe', '2016']
# ['volkswagen', 'beetle-convertible', '2015']
# ['volkswagen', 'beetle-convertible', '2016']

# %%
"""
Example urls:

http://www.edmunds.com/acura/ilx/2016/sedan/features-specs/
http://www.edmunds.com/lexus/ct-200h/2016/hatchback/features-specs/
"""

# %%
""""
Main class to crawl html from edmunds.com.

This class takes a specific url such as 'http://www.edmunds.com/lexus/ct-200h/2016/hatchback/features-specs/'

Six types of information about the specific car are parsed and structured:
1. interior color
2. exterior color
3. specification, such as engine, fuel and interior measurements
4. interior features
5. exterior features
6. safety features, such as airbags and stability control

The crawler is based on requests and BeautifulSoup.
The processing procedure:
- take an url, use requests to issue a request and get the content back as a string
- take the returned string from request as input, use BeautifulSoup to contruct a parse tree of the html
- parse info to get the six types of information we need

Always use try-except block, because many cars don't have all six types of information on the webpage.
"""

# %%
class CarInfoCrawler():
    def __init__(self, car_info):
        self.color_tree = None
        self.feature_spec_list = []
        self.request_status = False
        
        self.result = {}
        self.result['car description'] = {}
        self.result['car data'] = {}
        
        self.result['car description']['make'] = car_info['make']
        self.result['car description']['model'] = car_info['model']
        self.result['car description']['year'] = car_info['year']
        self.result['car description']['type'] = car_info['type']
            
        base_url = "http://www.edmunds.com"
        self.url = base_url + '/' + \
        '/'.join([self.result['car description']['make'], self.result['car description']['model'], \
                 self.result['car description']['year'], self.result['car description']['type']]) + \
                  '/features-specs/'
        
        self.result['car description']['url'] = self.url
        
        print 'initialize success'
        
    def request(self):
        try:
            spec_feature_request = requests.get(self.url)
        except:
            print 'request failed'
        print 'request success: ', self.url
        print 'request status: ', spec_feature_request.ok
        self.request_status = spec_feature_request.ok
        if self.request_status == True:
            soup = BeautifulSoup(spec_feature_request.content, 'lxml')
            self.color_tree = soup.find('div', id='colors-pod')
            self.feature_spec_list = soup.findAll('div', class_='feature-spec box')
            
            self.getColor()
            self.getSpec()
            self.getInteriorFeature()
            self.getExteriorFeature()
            self.getSafety()
        pprint(self.result)
        print 
        print
        
    def getColor(self):
        try:
            interior_color = []
            for outer_span in self.color_tree.find('p', text='Interior Colors').findNext('div').findAllNext('span'):
                for inner_span in outer_span.findAll('span'):
                    text = removeSpace(inner_span.text)
                    if text:
                        interior_color.append(text)
        except:
            print 'interior color unavailable'
            interior_color = 'unavailable'

        try:
            exterior_color = []
            for outer_span in self.color_tree.find('p', text='Exterior Colors').findNext('div').findAllNext('span'):
                for inner_span in outer_span.findAll('span'):
                    text = removeSpace(str(inner_span.text))
                    if text:
                        exterior_color.append(text)
        except:
            print 'exterior color unavailable'
            exterior_color = 'unavailable'
                    
        self.result['car data']['interior color'] = interior_color
        self.result['car data']['exterior color'] = exterior_color
        print 'get color done'
        
    def getSpec(self):
        try:
            spec_tree = self.feature_spec_list[0]
            spec_result = {}
            spec_h3 = spec_tree.findAll('h3')
            spec_table = spec_tree.findAll('table')
            for i in range(len(spec_h3)):
                spec = []
                if spec_h3[i].text != 'Suspension':
                    for tr in spec_table[i].findAll('tr'):
                        for td in tr.findAll('td'):
                            if td.label:
                                spec.append({
                                        str(td.label.text): str(td.span.text)
                                    })
                else:
                    for span in spec_table[i].findAll('span'):
                        spec.append(str(span.text))
                spec_result[str(spec_h3[i].text)] = spec
            self.result['car data']['specification'] = spec_result
        except:
            print 'spec unavailable'
            self.result['car data']['specification'] = 'unavailable'
        print 'get spec done'
        
    def getInteriorFeature(self):
        try:
            interior_tree = self.feature_spec_list[1]
            interior_result = {}
            counter = 0
            interior_h4 = interior_tree.findAll('h4')
            interior_table = interior_tree.findAll('table')
            for i in range(len(interior_h4)):
                feature = []
                for span in interior_table[counter].findAll('span'):
                    feature.append(str(span.text))

                next_table = interior_table[counter] .findNext('table')
                if counter < len(interior_table) - 1 and interior_table[counter].findNext('h4') == next_table.findNext('h4'):
                    for span in next_table.findAll('span'):
                        feature.append(str(span.text))
                    counter += 1

                counter += 1
                interior_result[str(interior_h4[i].text)] = feature
            self.result['car data']['interior feature'] = interior_result
        except:
            print 'interior feature unavailable'
            self.result['car data']['interior feature'] = 'unavailable'
        print 'get interior feature done'
            
            
    def getExteriorFeature(self):
        try:
            exterior_tree = self.feature_spec_list[2]
            counter = 0
            exterior_result = {}
            exterior_h4 = exterior_tree.findAll('h4')
            exterior_table = exterior_tree.findAll('table')
            for i in range(len(exterior_h4)):
                feature = []
                for span in exterior_table[counter].findAll('span'):
                    feature.append(str(span.text))

                next_table = exterior_table[counter] .findNext('table')
                if counter < len(exterior_table) - 1 and exterior_table[counter].findNext('h4') == next_table.findNext('h4'):
                    for span in next_table.findAll('span'):
                        feature.append(str(span.text))
                    counter += 1

                counter += 1
                exterior_result[str(exterior_h4[i].text)] = feature
            self.result['car data']['exterior feature'] = exterior_result
        except:
            print 'exterior unavailable'
            self.result['car data']['exterior feature'] = 'unavailable'
        print 'get exterior feature done'
        
    def getSafety(self):
        try:
            safety_tree = self.feature_spec_list[3]
            self.result['car data']['safety'] = []
            for table in safety_tree.findAll('table'):
                for span in table.findAll('span'):
                    self.result['car data']['safety'].append(str(span.text))
        except:
            print 'safery unavailable'
            self.result['car data']['safety'] = 'unavailable'
            
        print 'get safety done'

# %%
format_result = []
for car in car_list:
    crawler = CarInfoCrawler(car)
    crawler.request()
    result = all_car_result.append(crawler.result)
   
    format_result.append(result)
# Out:
# initialize success
# request success:  http://www.edmunds.com/acura/ilx/2015/sedan/features-specs/
# request status:  True
# get color done
# get spec done
# get interior feature done
# get exterior feature done
# safery unavailable
# get safety done
# {'car data': {'exterior color': ['Bellanova White Pearl',
#                                  'Crystal Black Pearl',
#                                  'Fathom Blue Pearl',
#                                  'Modern Steel Metallic',
#                                  'Silver Moon',
#                                  'Ebony, leather'],
#               'exterior feature': {'Roof and Glass': ['Intermittent wipers',
#                                                       'Rear defogger',
#                                                       'Power glass sunroof',
#                                                       'Remote sunroof operation'],
#                                    'Tires and Wheels': ['Alloy wheels',
#                                                         '17 x 7.0 in. wheels',
#                                                         'P215/45R17 87V tires',
#                                                         'All season tires',
#                                                         'Inside mounted spare tire',
#                                                         'Temporary spare tire']},
#               'interior color': ['Ebony, leather'],
#               'interior feature': {'Comfort': ['Interior air filtration',
#                                                'Dual zone climate controls - driver and passenger',
#                                                'Leather steering wheel',
#                                                'Turn signal in mirrors',
#                                                'Dual illuminating vanity mirrors'],
#                                    'Convenience': ['Cruise control',
#                                                    'Front and rear cupholders',
#                                                    'Front and rear door pockets',
#                                                    'Front seatback storage',
#                                                    'Electric speed-proportional power steering',
#                                                    'Tilt and telescopic steering wheel',
#                                                    'Transmission, cruise and audio controls on steering wheel',
#                                                    'Rear view with wide-angle and top view camera'],
#                                    'Front Seats': ['Multi-level heating passenger seat',
#                                                    '8 -way power driver seat',
#                                                    'Multi-level heating driver seat',
#                                                    'Height adjustable driver seat',
#                                                    'Leather',
#                                                    'Bucket front seats'],
#                                    'In Car Entertainment': ['Mast antenna',
#                                                             '7 total speakers',
#                                                             'AM/FM  stereo',
#                                                             'Speed sensitive volume control',
#                                                             'Auxiliary audio input and USB with external media control',
#                                                             '1 subwoofer(s)',
#                                                             'Radio data system',
#                                                             'USB connection'],
#                                    'Instrumentation': ['Clock',
#                                                        'Tachometer',
#                                                        'Trip computer',
#                                                        'External temperature display',
#                                                        'Low fuel level warning'],
#                                    'Power Features': ['Hands-free entry',
#                                                       'Reverse tilt driver mirror provides curb view when vehicle in reverse',
#                                                       '2 one-touch power windows',
#                                                       'Remote window operation'],
#                                    'Rear Seats': ['Folding rear seatback',
#                                                   'Folding with storage center armrest'],
#                                    'Telematics': ['Bluetooth wireless data link for hands-free phone']},
#               'safety': 'unavailable',
#               'specification': {'DriveTrain': [{'DRIVE TYPE': ' Front wheel drive'},
#                                                {'TRANSMISSION': ' 5-speed shiftable automatic'}],
#                                 'Engine & Performance': [{'BASE ENGINE SIZE': ' 2.0 L'},
#                                                          {'CAM TYPE': ' Single overhead cam (SOHC)'},
#                                                          {'CYLINDERS': ' Inline 4'},
#                                                          {'VALVES': ' 16'},
#                                                          {'VALVE TIMING': ' Variable'},
#                                                          {'TORQUE': ' 140 ft-lbs. @ 4300 rpm'},
#                                                          {'HORSEPOWER': ' 150 hp @ 6500 rpm'},
#                                                          {'TURNING CIRCLE': ' 36.1 ft.'}],
#                                 'Exterior Measurements': [{'WIDTH': '5 ft. 10.6 in. (70.6 in.)'},
#                                                           {'HEIGHT': '4 ft. 7.6 in. (55.6 in.)'},
#                                                           {'LENGTH': '14 ft. 11.1 in. (179.1 in.)'},
#                                                           {'WHEEL BASE': '8 ft. 9.1 in. (105.1 in.)'}],
#                                 'Fuel': [{'ENGINE TYPE': ' Gas'},
#                                          {'FUEL TYPE': ' Premium unleaded (recommended)'},
#                                          {'FUEL TANK CAPACITY': ' 13.2 gal.'},
#                                          {'RANGE IN MILES (CTY/HWY)': ' 316.8/462.0 mi.'},
#                                          {'EPA MILEAGE EST. (CTY/HWY)': ' 24/35 mpg'}],
#                                 'Interior Measurements': [{'FRONT HEAD ROOM': ' 38.0 in.'},
#                                                           {'FRONT HIP ROOM': ' 50.2 in.'},
#                                                           {'FRONT LEG ROOM': ' 42.3 in.'},
#                                                           {'FRONT SHOULDER ROOM': ' 55.6 in.'},
#                                                           {'REAR HIP ROOM': ' 51.7 in.'},
#                                                           {'REAR HEAD ROOM': ' 35.9 in.'},
#                                                           {'REAR LEG ROOM': ' 34.0 in.'},
#                                                           {'REAR SHOULDER ROOM': ' 53.5 in.'}],
#                                 'Suspension': ['MacPherson strut front suspension',
#                                                'Multi-link rear suspension',
#                                                'Four-wheel independent suspension',
#                                                'Front and rear stabilizer bar'],
#                                 'Warranty': [{'BASIC': ' 4 yr./ 50000 mi.'},
#                                              {'DRIVETRAIN': ' 6 yr./ 70000 mi.'},
#                                              {'ROADSIDE': ' 4 yr./ 50000 mi.'}],
#                                 'Weights and Capacities': [{'EPA INTERIOR VOLUME': ' 101.6 cu.ft.'},
#                                                            {'CURB WEIGHT': ' 2955 lbs.'},
#                                                            {'CARGO CAPACITY, ALL SEATS IN PLACE': ' 12.3 cu.ft.'}]}},
#  'car description': {'make': 'acura',
#                      'model': 'ilx',
#                      'type': 'sedan',
#                      'url': 'http://www.edmunds.com/acura/ilx/2015/sedan/features-specs/',
#                      'year': '2015'},
#  'safety': []}
#
#
# initialize success
# request success:  http://www.edmunds.com/acura/ilx/2016/sedan/features-specs/
# request status:  True
# get color done
# get spec done
# get interior feature done
# get exterior feature done
# safery unavailable
# get safety done
# {'car data': {'exterior color': ['Basque Red Pearl II',
#                                  'Bellanova White Pearl',
#                                  'Catalina Blue Pearl',
#                                  'Crystal Black Pearl',
#                                  'Graphite Luster Metallic',
#                                  'Slate Silver Metallic',
#                                  'Ebony, leatherette',
#                                  'Graystone, leatherette',
#                                  'Parchment, leatherette'],
#               'exterior feature': {'Roof and Glass': ['Variable intermittent wipers',
#                                                       'Rear defogger',
#                                                       'Power glass sunroof',
#                                                       'Remote sunroof operation'],
#                                    'Tires and Wheels': ['Alloy wheels',
#                                                         '17 x 7.0 in. wheels',
#                                                         'P215/45R17 87V tires',
#                                                         'All season tires']},
#               'interior color': ['Ebony, leatherette',
#                                  'Graystone, leatherette',
#                                  'Parchment, leatherette'],
#               'interior feature': {'Comfort': ['Interior air filtration',
#                                                'Dual zone climate controls - driver and passenger',
#                                                'Leather steering wheel',
#                                                'Dual illuminating vanity mirrors'],
#                                    'Convenience': ['Cruise control',
#                                                    'Front and rear cupholders',
#                                                    'Front door pockets',
#                                                    'Electric power steering',
#                                                    'Tilt and telescopic steering wheel',
#                                                    'Transmission, cruise and audio controls on steering wheel',
#                                                    'Rear view camera'],
#                                    'Front Seats': ['Multi-level heating passenger seat',
#                                                    '8 -way power driver seat',
#                                                    'Multi-level heating driver seat',
#                                                    'Height adjustable driver seat',
#                                                    'Leatherette',
#                                                    'Sport front seats'],
#                                    'In Car Entertainment': ['6 total speakers',
#                                                             'AM/FM  stereo',
#                                                             'Speed sensitive volume control',
#                                                             'Auxiliary audio input and USB with external media control',
#                                                             'USB connection'],
#                                    'Instrumentation': ['Clock',
#                                                        'Tachometer',
#                                                        'Trip computer',
#                                                        'External temperature display'],
#                                    'Power Features': ['Remote keyless power door locks',
#                                                       '2 one-touch power windows'],
#                                    'Rear Seats': ['Folding rear seatback',
#                                                   'Folding center armrest'],
#                                    'Telematics': ['Bluetooth wireless data link for hands-free phone']},
#               'safety': 'unavailable',
#               'specification': {'DriveTrain': [{'DRIVE TYPE': ' Front wheel drive'},
#                                                {'TRANSMISSION': ' 8-speed automated manual'}],
#                                 'Engine & Performance': [{'BASE ENGINE SIZE': ' 2.4 L'},
#                                                          {'CAM TYPE': ' Double overhead cam (DOHC)'},
#                                                          {'CYLINDERS': ' Inline 4'},
#                                                          {'VALVES': ' 16'},
#                                                          {'VALVE TIMING': ' Variable'},
#                                                          {'TORQUE': ' 180 ft-lbs. @ 3800 rpm'},
#                                                          {'HORSEPOWER': ' 201 hp @ 6800 rpm'},
#                                                          {'TURNING CIRCLE': ' 36.8 ft.'}],
#                                 'Exterior Measurements': [{'WIDTH': '5 ft. 10.6 in. (70.6 in.)'},
#                                                           {'HEIGHT': '4 ft. 7.6 in. (55.6 in.)'},
#                                                           {'LENGTH': '15 ft. 1.9 in. (181.9 in.)'},
#                                                           {'WHEEL BASE': '8 ft. 9.1 in. (105.1 in.)'}],
#                                 'Fuel': [{'ENGINE TYPE': ' Gas'},
#                                          {'FUEL TYPE': ' Premium unleaded (recommended)'},
#                                          {'FUEL TANK CAPACITY': ' 13.2 gal.'},
#                                          {'RANGE IN MILES (CTY/HWY)': ' 330.0/475.2 mi.'},
#                                          {'EPA MILEAGE EST. (CTY/HWY)': ' 25/36 mpg'}],
#                                 'Interior Measurements': [{'FRONT HEAD ROOM': ' 38.0 in.'},
#                                                           {'FRONT HIP ROOM': ' 50.3 in.'},
#                                                           {'FRONT LEG ROOM': ' 42.3 in.'},
#                                                           {'FRONT SHOULDER ROOM': ' 55.6 in.'},
#                                                           {'REAR HIP ROOM': ' 51.7 in.'},
#                                                           {'REAR HEAD ROOM': ' 35.9 in.'},
#                                                           {'REAR LEG ROOM': ' 34.0 in.'},
#                                                           {'REAR SHOULDER ROOM': ' 53.5 in.'}],
#                                 'Suspension': ['Four-wheel independent suspension',
#                                                'Front and rear stabilizer bar'],
#                                 'Warranty': [{'BASIC': ' 4 yr./ 50000 mi.'},
#                                              {'DRIVETRAIN': ' 6 yr./ 70000 mi.'},
#                                              {'ROADSIDE': ' 4 yr./ 50000 mi.'}],
#                                 'Weights and Capacities': [{'EPA INTERIOR VOLUME': ' 101.6 cu.ft.'},
#                                                            {'CURB WEIGHT': ' 3093 lbs.'},
#                                                            {'CARGO CAPACITY, ALL SEATS IN PLACE': ' 12.3 cu.ft.'}]}},
#  'car description': {'make': 'acura',
#                      'model': 'ilx',
#                      'type': 'sedan',
#                      'url': 'http://www.edmunds.com/acura/ilx/2016/sedan/features-specs/',
#                      'year': '2016'},
#  'safety': []}
#
#
# initialize success
# request success:  http://www.edmunds.com/acura/mdx/2015/suv/features-specs/
# request status:  True
# get color done
# get spec done
# get interior feature done
# get exterior feature done
# safery unavailable
# get safety done
# {'car data': {'exterior color': ['Crystal Black Pearl',
#                                  'Dark Cherry Pearl',
#                                  'Graphite Luster Metallic',
#                                  'Silver Moon',
#                                  'White Diamond Pearl',
#                                  'Ebony, leather',
#                                  'Graystone, leather',
#                                  'Parchment, leather'],
#               'exterior feature': {'Body': ['Rear spoiler'],
#                                    'Doors': ['Fixed lifgate window',
#                                              'Rear power liftgate door'],
#                                    'Roof and Glass': ['Variable intermittent wipers',
#                                                       'Privacy glass',
#                                                       'Rear defogger',
#                                                       'Intermittent rear wiper',
#                                                       'Power glass sunroof',
#                                                       'Remote sunroof operation'],
#                                    'Tires and Wheels': ['Alloy wheels',
#                                                         '18 x 8.0 in. wheels',
#                                                         'P245/60R18 tires',
#                                                         'All season tires',
#                                                         'Underbody mounted spare tire',
#                                                         'Temporary spare tire']},
#               'interior color': ['Ebony, leather',
#                                  'Graystone, leather',
#                                  'Parchment, leather'],
#               'interior feature': {'Comfort': ['Interior air filtration',
#                                                'Three zone climate control',
#                                                'Leather steering wheel',
#                                                'Turn signal in mirrors',
#                                                'Electrochromatic inside rearview mirror',
#                                                'Dual illuminating vanity mirrors'],
#                                    'Convenience': ['Cruise control',
#                                                    'Front, rear and 3rd row cupholders',
#                                                    'Front and rear door pockets',
#                                                    'Front seatback storage',
#                                                    'Electric speed-proportional power steering',
#                                                    'Universal remote transmitter (for garage door, security system, etc.)',
#                                                    'Tilt and telescopic steering wheel',
#                                                    'Transmission, cruise and audio controls on steering wheel',
#                                                    'Rear view camera'],
#                                    'Front Seats': ['Multi-level heating passenger seat',
#                                                    '8 -way power passenger seat',
#                                                    '8 -way power driver seat',
#                                                    'Multi-level heating driver seat',
#                                                    'Driver seat with power adjustable lumbar support',
#                                                    'Height adjustable driver seat',
#                                                    'Height adjustable passenger seat',
#                                                    'Leather',
#                                                    'Bucket front seats'],
#                                    'In Car Entertainment': ['Element antenna',
#                                                             '8 total speakers',
#                                                             '432 watts stereo output',
#                                                             'AM/FM  stereo',
#                                                             'Satellite radio satellite radio',
#                                                             'Auxiliary audio input and USB with external media control',
#                                                             '1 subwoofer(s)',
#                                                             'Radio data system',
#                                                             'USB connection'],
#                                    'Instrumentation': ['Clock',
#                                                        'Tachometer',
#                                                        'Trip computer',
#                                                        'External temperature display',
#                                                        'Low fuel level warning'],
#                                    'Memorized settings': ['Memorized settings for 2 drivers',
#                                                           'Memorized settings includes steering wheel'],
#                                    'Power Features': ['Hands-free entry',
#                                                       'Reverse tilt dual mirrors provides curb view when vehicle in reverse',
#                                                       '4 one-touch power windows',
#                                                       'Remote window operation'],
#                                    'Rear Seats': ['Split-folding rear seatback',
#                                                   'Reclining rear seats',
#                                                   'Folding with storage center armrest',
#                                                   'Manual folding split-bench third row seats',
#                                                   'Rear ventilation ducts with fan control'],
#                                    'Telematics': ['Bluetooth wireless data link for hands-free phone']},
#               'safety': 'unavailable',
#               'specification': {'DriveTrain': [{'DRIVE TYPE': ' Front wheel drive'},
#                                                {'TRANSMISSION': ' 6-speed shiftable automatic'}],
#                                 'Engine & Performance': [{'BASE ENGINE SIZE': ' 3.5 L'},
#                                                          {'CAM TYPE': ' Single overhead cam (SOHC)'},
#                                                          {'CYLINDERS': ' V6'},
#                                                          {'VALVES': ' 24'},
#                                                          {'VALVE TIMING': ' Variable'},
#                                                          {'TORQUE': ' 267 ft-lbs. @ 4500 rpm'},
#                                                          {'HORSEPOWER': ' 290 hp @ 6200 rpm'},
#                                                          {'TURNING CIRCLE': ' 37.6 ft.'}],
#                                 'Exterior Measurements': [{'HEIGHT': '5 ft. 7.6 in. (67.6 in.)'},
#                                                           {'LENGTH': '16 ft. 1.6 in. (193.6 in.)'},
#                                                           {'WHEEL BASE': '9 ft. 3 in. (111 in.)'}],
#                                 'Fuel': [{'ENGINE TYPE': ' Gas'},
#                                          {'FUEL TYPE': ' Premium unleaded (recommended)'},
#                                          {'FUEL TANK CAPACITY': ' 19.5 gal.'},
#                                          {'RANGE IN MILES (CTY/HWY)': ' 390.0/546.0 mi.'},
#                                          {'EPA MILEAGE EST. (CTY/HWY)': ' 20/28 mpg'}],
#                                 'Interior Measurements': [{'FRONT HEAD ROOM': ' 38.1 in.'},
#                                                           {'FRONT HIP ROOM': ' 57.5 in.'},
#                                                           {'FRONT LEG ROOM': ' 41.4 in.'},
#                                                           {'FRONT SHOULDER ROOM': ' 61.1 in.'},
#                                                           {'REAR HIP ROOM': ' 57.8 in.'},
#                                                           {'REAR HEAD ROOM': ' 38.3 in.'},
#                                                           {'REAR LEG ROOM': ' 36.6 in.'},
#                                                           {'REAR SHOULDER ROOM': ' 59.1 in.'}],
#                                 'Suspension': ['MacPherson strut front suspension',
#                                                'Multi-link rear suspension',
#                                                'Four-wheel independent suspension',
#                                                'Front and rear stabilizer bar'],
#                                 'Warranty': [{'BASIC': ' 4 yr./ 50000 mi.'},
#                                              {'DRIVETRAIN': ' 6 yr./ 70000 mi.'},
#                                              {'ROADSIDE': ' 4 yr./ 50000 mi.'}],
#                                 'Weights and Capacities': [{'MAXIMUM TOWING CAPACITY**': ' 3500 lbs.'},
#                                                            {'CURB WEIGHT': ' 4025 lbs.'},
#                                                            {'ANGLE OF APPROACH': ' 14.9 degrees'},
#                                                            {'ANGLE OF DEPARTURE': ' 19.4 degrees'},
#                                                            {'CARGO CAPACITY, ALL SEATS IN PLACE': ' 14.8 cu.ft.'},
#                                                            {'MAXIMUM CARGO CAPACITY': ' 68.4 cu.ft.'}]}},
#  'car description': {'make': 'acura',
#                      'model': 'mdx',
#                      'type': 'suv',
#                      'url': 'http://www.edmunds.com/acura/mdx/2015/suv/features-specs/',
#                      'year': '2015'},
#  'safety': []}
#
#
# initialize success
# request success:  http://www.edmunds.com/acura/mdx/2016/suv/features-specs/
# request status:  True
# get color done
# get spec done
# get interior feature done
# get exterior feature done
# safery unavailable
# get safety done
# {'car data': {'exterior color': ['Crystal Black Pearl',
#                                  'Dark Cherry Pearl',
#                                  'Graphite Luster Metallic',
#                                  'Lunar Silver Metallic',
#                                  'White Diamond Pearl',
#                                  'Ebony, leather',
#                                  'Graystone, leather',
#                                  'Parchment, leather'],
#               'exterior feature': {'Body': ['Rear spoiler'],
#                                    'Doors': ['Fixed lifgate window',
#                                              'Rear power liftgate door'],
#                                    'Roof and Glass': ['Variable intermittent wipers',
#                                                       'Privacy glass',
#                                                       'Rear defogger',
#                                                       'Intermittent rear wiper',
#                                                       'Power glass sunroof',
#                                                       'Remote sunroof operation'],
#                                    'Tires and Wheels': ['Alloy wheels',
#                                                         '18 x 8.0 in. wheels',
#                                                         'P245/60R H tires',
#                                                         'All season tires',
#                                                         'Underbody mounted spare tire',
#                                                         'Temporary spare tire']},
#               'interior color': ['Ebony, leather',
#                                  'Graystone, leather',
#                                  'Parchment, leather'],
#               'interior feature': {'Comfort': ['Interior air filtration',
#                                                'Three zone climate control',
#                                                'Leather steering wheel',
#                                                'Turn signal in mirrors',
#                                                'Electrochromatic inside rearview mirror',
#                                                'Dual illuminating vanity mirrors'],
#                                    'Convenience': ['Cruise control',
#                                                    'Front, rear and 3rd row cupholders',
#                                                    'Front and rear door pockets',
#                                                    'Overhead console with storage',
#                                                    'Front seatback storage',
#                                                    'Electric power steering',
#                                                    'Universal remote transmitter (for garage door, security system, etc.)',
#                                                    'Tilt and telescopic steering wheel',
#                                                    'Transmission, cruise and audio controls on steering wheel',
#                                                    'Rear view camera'],
#                                    'Front Seats': ['Multi-level heating passenger seat',
#                                                    '8 -way power passenger seat',
#                                                    '8 -way power driver seat',
#                                                    'Multi-level heating driver seat',
#                                                    'Driver seat with power adjustable lumbar support',
#                                                    'Height adjustable driver seat',
#                                                    'Height adjustable passenger seat',
#                                                    'Leather',
#                                                    'Bucket front seats'],
#                                    'In Car Entertainment': ['8 total speakers',
#                                                             '432 watts stereo output',
#                                                             'AM/FM  stereo',
#                                                             'Satellite radio satellite radio',
#                                                             'Speed sensitive volume control',
#                                                             'Auxiliary audio input and USB with external media control',
#                                                             '1 subwoofer(s)',
#                                                             'USB connection'],
#                                    'Instrumentation': ['Clock',
#                                                        'Tachometer',
#                                                        'Trip computer',
#                                                        'External temperature display',
#                                                        'Compass'],
#                                    'Memorized settings': ['Memorized settings includes climate control',
#                                                           'Memorized settings for 2 drivers',
#                                                           'Memorized settings includes steering wheel'],
#                                    'Power Features': ['Hands-free entry',
#                                                       'Reverse tilt dual mirrors provides curb view when vehicle in reverse',
#                                                       '4 one-touch power windows'],
#                                    'Rear Seats': ['Split-folding rear seatback',
#                                                   'Reclining rear seats',
#                                                   'Folding with storage center armrest',
#                                                   'Manual folding split-bench third row seats',
#                                                   'Rear ventilation ducts with fan control'],
#                                    'Telematics': ['Bluetooth wireless data link for hands-free phone']},
#               'safety': 'unavailable',
#               'specification': {'DriveTrain': [{'DRIVE TYPE': ' Front wheel drive'},
#                                                {'TRANSMISSION': ' 9-speed shiftable automatic'}],
#                                 'Engine & Performance': [{'BASE ENGINE SIZE': ' 3.5 L'},
#                                                          {'CAM TYPE': ' Single overhead cam (SOHC)'},
#                                                          {'CYLINDERS': ' V6'},
#                                                          {'VALVES': ' 24'},
#                                                          {'VALVE TIMING': ' Variable'},
#                                                          {'TORQUE': ' 267 ft-lbs. @ 4500 rpm'},
#                                                          {'HORSEPOWER': ' 290 hp @ 6200 rpm'},
#                                                          {'TURNING CIRCLE': ' 38.7 ft.'}],
#                                 'Exterior Measurements': [{'HEIGHT': '5 ft. 7.6 in. (67.6 in.)'},
#                                                           {'LENGTH': '16 ft. 1.6 in. (193.6 in.)'},
#                                                           {'WHEEL BASE': '9 ft. 3 in. (111 in.)'}],
#                                 'Fuel': [{'ENGINE TYPE': ' Gas'},
#                                          {'FUEL TYPE': ' Premium unleaded (recommended)'},
#                                          {'FUEL TANK CAPACITY': ' 19.5 gal.'},
#                                          {'RANGE IN MILES (CTY/HWY)': ' 370.5/526.5 mi.'},
#                                          {'EPA MILEAGE EST. (CTY/HWY)': ' 19/27 mpg'}],
#                                 'Interior Measurements': [{'FRONT HEAD ROOM': ' 38.1 in.'},
#                                                           {'FRONT HIP ROOM': ' 59.0 in.'},
#                                                           {'FRONT LEG ROOM': ' 41.4 in.'},
#                                                           {'FRONT SHOULDER ROOM': ' 61.1 in.'},
#                                                           {'REAR HIP ROOM': ' 57.8 in.'},
#                                                           {'REAR HEAD ROOM': ' 38.3 in.'},
#                                                           {'REAR LEG ROOM': ' 36.6 in.'},
#                                                           {'REAR SHOULDER ROOM': ' 59.1 in.'}],
#                                 'Suspension': ['Four-wheel independent suspension',
#                                                'Front and rear stabilizer bar'],
#                                 'Warranty': [{'BASIC': ' 4 yr./ 50000 mi.'},
#                                              {'DRIVETRAIN': ' 6 yr./ 70000 mi.'},
#                                              {'ROADSIDE': ' 4 yr./ 50000 mi.'}],
#                                 'Weights and Capacities': [{'MAXIMUM TOWING CAPACITY**': ' 3500 lbs.'},
#                                                            {'EPA INTERIOR VOLUME': ' 147.3 cu.ft.'},
#                                                            {'CURB WEIGHT': ' 3960 lbs.'},
#                                                            {'ANGLE OF APPROACH': ' 14.9 degrees'},
#                                                            {'ANGLE OF DEPARTURE': ' 15.2 degrees'},
#                                                            {'CARGO CAPACITY, ALL SEATS IN PLACE': ' 15.0 cu.ft.'},
#                                                            {'MAXIMUM CARGO CAPACITY': ' 68.4 cu.ft.'}]}},
#  'car description': {'make': 'acura',
#                      'model': 'mdx',
#                      'type': 'suv',
#                      'url': 'http://www.edmunds.com/acura/mdx/2016/suv/features-specs/',
#                      'year': '2016'},
#  'safety': []}
#
#
# initialize success
# request failed
# request success:  http://www.edmunds.com/acura/rdx/2015/suv/features-specs/
# request status:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-77-e6b6aecac79b> in <module>()
#       2 for car in car_list:
#       3     crawler = CarInfoCrawler(car)
# ----> 4     crawler.request()
#       5     result = all_car_result.append(crawler.result)
#       6
#
# <ipython-input-76-cc3ac8900016> in request(self)
#      27             print 'request failed'
#      28         print 'request success: ', self.url
# ---> 29         print 'request status: ', spec_feature_request.ok
#      30         self.request_status = spec_feature_request.ok
#      31         if self.request_status == True:
#
# UnboundLocalError: local variable 'spec_feature_request' referenced before assignment

# %%
count = 0
for result in format_result:
    if not result:
        count += 1
print count
# Out:
# 0

# %%
with open('saved-data/json/car_data.json', 'r') as f:
    car_info_all = json.load(f)

# %%
count = 0
for car in car_info_all:
    if int(car['car description']['year'])  == 2014:
        count += 1
print count
# Out:
# 19
